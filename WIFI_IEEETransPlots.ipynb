# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from google.colab import drive
import matplotlib as mlp
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
from pandas.io.excel import read_excel
from google.colab import files

drive.mount('/content/drive')
#dados = read_excel('/content/drive/MyDrive/Medições RNI/WIFI/respostas_formulario_de_medicao_wi-fi (1).xlsx')
dados = read_excel('/content/drive/MyDrive/WIFI/respostas_formulario_de_medicao_wi-fi (1).xlsx')
fontPar = 12
# Out:
# <ipython-input-60-ec28480395c9>:8: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Maior Valor médio
fig, ax = plt.subplots()
dados.hist(column='Ano de fabricação do dispositivo Wi-Fi', rwidth= 0.9,label= 'Quantidade de equipamentos com base no ano de fabricação',align='mid',color='blue', ax=ax)
plt.rcParams["figure.figsize"] = (10,8)
plt.title('')
plt.xlabel('Ano de Fabricação', fontsize=fontPar)
plt.ylabel('Quantidade de Pontos de Acesso', fontsize=fontPar)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
fig.savefig('Fig7_ok.png',dpi=300)
files.download('Fig7_ok.png')
plt.show()

# %%
# Mario valor médio
fig, ax = plt.subplots()
x= dados['Ano de fabricação do dispositivo Wi-Fi']
y= dados['Valor médio para WI-FI DESLIGADO']
plt.bar(x,y,color='red')
plt.xlabel('Ano de Fabricação do Ponto de Acesso', fontsize=fontPar)
plt.ylabel('Intensidade de Campo Elétrico (V/m)', fontsize=fontPar)
plt.rcParams["figure.figsize"] = (10,8)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.grid(zorder=0)
fig.savefig('Fig9_ok.png',dpi=300)
files.download('Fig9_ok.png')
plt.show ()

# %%
import pandas as pd
colunas_selecionadas = ['Marca do dispositivo Wi-Fi:','Ano de fabricação do dispositivo Wi-Fi','Valor médio para 2,4 GHz CARREGADO','Valor médio para 5 GHz CARREGADO','Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)']

# %%
Ano = ['Ano de fabricação do dispositivo Wi-Fi']
Campo_Elétrico = ['Valor médio para WI-FI DESLIGADO']
Marca_do_Roteador = ['Marca do dispositivo Wi-Fi:']

# %%
desligado_selecionado = ['Valor médio para WI-FI DESLIGADO', 'Valor de pico para WI-FI DESLIGADO','Marca do dispositivo Wi-Fi:']
analise_desligado = dados.filter(items=desligado_selecionado)

# %%
analise_desligado.head()
# Out:
#    Valor médio para WI-FI DESLIGADO  Valor de pico para WI-FI DESLIGADO  \
# 0                              0.13                                1.74
# 1                              0.08                                0.84
# 2                              0.13                                0.89
# 3                              0.09                                0.64
# 4                              0.04                                0.68
#
#   Marca do dispositivo Wi-Fi:
# 0                         DZS
# 1                   Easy4link
# 2                   Intelbras
# 3                         CBN
# 4                 Technicolor

# %%
analise_desligado.reset_index
# Out:
# <bound method DataFrame.reset_index of     Valor médio para WI-FI DESLIGADO  Valor de pico para WI-FI DESLIGADO  \
# 0                               0.13                                1.74
# 1                               0.08                                0.84
# 2                               0.13                                0.89
# 3                               0.09                                0.64
# 4                               0.04                                0.68
# 5                               0.05                                0.66
# 6                               0.26                                0.43
# 7                               0.08                                0.65
# 8                               0.05                                0.75
# 9                               0.78                                1.10
# 10                              0.07                                1.26
# ...

# %%
fig, ax = plt.subplots()
y1=analise_desligado['Valor médio para WI-FI DESLIGADO']
y2= analise_desligado['Valor de pico para WI-FI DESLIGADO']
indexSemZero = ~( analise_desligado['Valor de pico para WI-FI DESLIGADO'] == 0)
x = range(1,y1[indexSemZero].shape[0]+1)
plt.plot(x,y1[indexSemZero],c='blue',label='Valor médio para ponto de acesso desligado',ls='-')
plt.plot(x,y2[indexSemZero],c='red',label='Valor de pico para ponto de acesso desligado',ls='-')
plt.legend()
#plt.title('Intensidade do Campo Elétrico', color = 'black')
plt.xlabel('Pontos de Acesso', fontsize=fontPar)
plt.ylabel('Intensidade de Campo Elétrico (V/m)', fontsize=fontPar)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.rcParams["figure.figsize"] = (10,8)
fig.savefig('Fig6_ok.png',dpi=300)
files.download('Fig6_ok.png')
plt.show ()

# %%
colunas_selecionadas= ['Valor médio para 2,4 GHz CARREGADO','Valor médio para 5 GHz CARREGADO','Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)', 'Serviço']
microdados_selecionados= dados.filter(items=colunas_selecionadas)
microdados_selecionados.head()
# Out:
#    Valor médio para 2,4 GHz CARREGADO  Valor médio para 5 GHz CARREGADO  \
# 0                                1.41                              1.43
# 1                                0.83                              0.96
# 2                                1.66                              2.08
# 3                                1.58                              1.43
# 4                                1.01                              0.69
#
#    Valor médio para 2,4 GHz  + 5 GHz (CARREGADO) Serviço
# 0                                           1.14    FTTH
# 1                                           0.87    FTTH
# 2                                           1.83    FTTH
# 3                                           2.17     HFC
# 4                                           0.69    FTTH

# %%
microdados_selecionados.reset_index
# Out:
# <bound method DataFrame.reset_index of     Valor médio para 2,4 GHz CARREGADO  Valor médio para 5 GHz CARREGADO  \
# 0                                 1.41                              1.43
# 1                                 0.83                              0.96
# 2                                 1.66                              2.08
# 3                                 1.58                              1.43
# 4                                 1.01                              0.69
# 5                                 0.20                              0.39
# 6                                 0.67                              1.92
# 7                                 0.34                              0.00
# 8                                 2.03                              2.32
# 9                                 2.06                              2.02
# 10                                1.92                              0.76
# ...

# %%
microdados_selecionados.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mlp
from IPython.display import set_matplotlib_formats
fig, ax = plt.subplots()
#fig,ax=plt.subplots(figsize=(12,8))
# tirar os zeros das medições de 5GHz
indexSemZero = ~( microdados_selecionados['Valor médio para 5 GHz CARREGADO'] == 0)
y1= microdados_selecionados['Valor médio para 2,4 GHz CARREGADO']
y2= microdados_selecionados['Valor médio para 5 GHz CARREGADO']
y3= microdados_selecionados['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)']
x = range(1,y1[indexSemZero].shape[0]+1)
plt.plot(x,y1[indexSemZero],c='blue',label='2,4 GHz',ls='-.')
plt.plot(x,y2[indexSemZero],c='red',label='5 GHz',ls='-')
plt.plot(x,y3[indexSemZero],c='black',label='2,4 e 5 GHz',ls='--')
plt.legend()
#plt.title('Intensidade do Campo Elétrico', color = 'black')
plt.ylabel('Intensidade de Campo Elétrico (V/m)', fontsize=fontPar)
plt.xlabel('Pontos de Acesso', fontsize=fontPar)
#plt.figure(figsize = (8,5), dpi=120)
plt.rcParams["figure.figsize"] = (10,8)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
fig.savefig('Fig9_ok.png',dpi=300)
files.download('Fig9_ok.png')
plt.show ()

# %% [markdown]
# **Gráficos Artigo SBrT**

# %%
colunas_selecionadas= ['Ano de fabricação do dispositivo Wi-Fi','Valor médio para 2,4 GHz CARREGADO','Valor médio para 5 GHz CARREGADO','Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)', 'Serviço','Valor de pico para 2,4 GHz CARREGADO', 'Valor de pico para 5 GHz CARREGADO', 'Valor de pico para 2,4 GHz  + 5 GHz (CARREGADO)', 'Valor médio para WI-FI DESLIGADO']
microdados_selecionados= dados.filter(items=colunas_selecionadas)
microdados_selecionados.head()
# Out:
#    Ano de fabricação do dispositivo Wi-Fi  Valor médio para 2,4 GHz CARREGADO  \
# 0                                    2021                                1.41
# 1                                    2020                                0.83
# 2                                    2020                                1.66
# 3                                    2020                                1.58
# 4                                    2020                                1.01
#
#    Valor médio para 5 GHz CARREGADO  \
# 0                              1.43
# 1                              0.96
# 2                              2.08
# 3                              1.43
# 4                              0.69
#
#    Valor médio para 2,4 GHz  + 5 GHz (CARREGADO) Serviço  \
# 0                                           1.14    FTTH
# 1                                           0.87    FTTH
# 2                                           1.83    FTTH
# ...

# %%
plt.figure(figsize = (8,5), dpi=120)
y1= microdados_selecionados['Valor médio para 2,4 GHz CARREGADO']
y2= microdados_selecionados['Valor de pico para 2,4 GHz CARREGADO']
y3= microdados_selecionados['Valor médio para WI-FI DESLIGADO']
indexSemZero = ~( microdados_selecionados['Valor de pico para 2,4 GHz CARREGADO'] == 0)
#print(indexSemZero)
x = range(1,y1.shape[0]+1)
plt.plot(x,y1,c='green',label='Valor médio - 2,4 GHz',ls='-.')
plt.plot(x,y2,c='purple',label='Valor de pico - 2,4 GHz',ls='-')
plt.plot(x,y3,c='black',label='Valor médio - equipamento desligado',ls='--')
plt.legend()
#plt.title('Intensidade do Campo Elétrico', color = 'black')
plt.ylabel('Intensidade de Campo Elétrico (V/m)')
plt.xlabel('Pontos de Acesso')
plt.ylim(0, 8)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.show()

print('Maior média de 2,4 GHz = {}'.format(y1.max()))
# Out:
# Maior média de 2,4 GHz = 4.66

# %%
plt.figure(figsize = (8,5), dpi=120)
indexSemZero = ~( microdados_selecionados['Valor médio para 5 GHz CARREGADO'] == 0)
ye1= microdados_selecionados['Valor médio para 5 GHz CARREGADO']
ye2= microdados_selecionados['Valor de pico para 5 GHz CARREGADO']
ye3= microdados_selecionados['Valor médio para WI-FI DESLIGADO']
x = range(1,ye1[indexSemZero].shape[0]+1)
plt.plot(x,ye1[indexSemZero],c='green',label='Valor médio - 5 GHz',ls='-.')
plt.plot(x,ye2[indexSemZero],c='purple',label='Valor de pico - 5 GHz',ls='-')
plt.plot(x,ye3[indexSemZero],c='black',label='Valor médio - equipamento desligado',ls='--')
plt.legend()
#plt.title('Intensidade do Campo Elétrico', color = 'black')
plt.ylabel('Intensidade de Campo Elétrico (V/m)')
plt.xlabel('Ponto de Acesso')
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.ylim(0, 8.5)
plt.show()

print('Maior média de 5 GHz = {}'.format(ye1.max()))
# Out:
# Maior média de 5 GHz = 4.34

# %%
#fig,ax=plt.subplots(figsize=(12,8))
plt.figure(figsize = (8,5), dpi=120)
indexSemZero = ~( microdados_selecionados['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)'] == 0)
yb1= microdados_selecionados['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)']
yb2= microdados_selecionados['Valor de pico para 2,4 GHz  + 5 GHz (CARREGADO)']
yb3= microdados_selecionados['Valor médio para WI-FI DESLIGADO']
x = range(1,yb1[indexSemZero].shape[0]+1)
plt.plot(x,yb1[indexSemZero],c='green',label='Valor médio - 2.4 GHz + 5 GHz',ls='-.')
plt.plot(x,yb2[indexSemZero],c='purple',label='Valor de pico - 2.4 GHz + 5 GHz',ls='-')
plt.plot(x,yb3[indexSemZero],c='black',label='Valor médio - equipamento desligado',ls='--')
plt.legend()
#plt.title('Intensidade do Campo Elétrico', color = 'black')
plt.ylabel('Intensidade de Campo Elétrico (V/m)')
plt.xlabel('Ponto de Acesso')
plt.ylim(0, 8.5)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
plt.show()

print('Maior média de 2.4 e 5 GHz = {}'.format(yb1.max()))
# Out:
# Maior média de 2.4 e 5 GHz = 4.35

# %%
# Maior valor das médias por ano.
import matplotlib.pyplot as plt
import plotly.express as px
fig,ax= plt.subplots()
microdados_selecionados_per_year = microdados_selecionados
x=microdados_selecionados['Ano de fabricação do dispositivo Wi-Fi']
width_bar=0.30
ym= microdados_selecionados['Valor médio para 2,4 GHz CARREGADO']
yp= microdados_selecionados['Valor de pico para 2,4 GHz CARREGADO']
yd= microdados_selecionados['Valor médio para WI-FI DESLIGADO']
#fig,ax = plt.subplots(figsize = (8,5), dpi=120)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
barra_before=ax.bar(x-(width_bar),ym,width_bar,color ='grey',align='edge',label='Valor médio para 2,4 GHz' )
barra_medium=ax.bar(x,yp,width_bar,color ='red',align='edge',label='Valor de pico para 2,4 GHz' )
barra_aftter=ax.bar(x+(width_bar),yd,width_bar, color ='black',align='edge',label='Equipamento desligado' )
eixox=x
plt.xticks(x,eixox)
plt.ylim(0, 8)
#plt.title("Intensidade de campo elétrico ")
plt.xlabel('Ano de Fabricação do Ponto de Acesso')
plt.ylabel('Intensidade de Campo elétrico (V/m)')
plt.legend()
plt.rcParams["figure.figsize"] = (10,8)
fig.savefig('Fig8_ok.png',dpi=300)
files.download('Fig8_ok.png')


plt.show()

print('maior média = {}'.format(np.max(ym)))
print('maior pico = {}'.format(np.max(yp)))
# Out:
# maior média = 4.66
# maior pico = 7.16

# %%
# valor média das médias por ano (se for fazer esse gráfico para as outros frequências, precisa tirar os valores zerados de 5GHz)
import matplotlib.pyplot as plt
import plotly.express as px
fig,ax = plt.subplots(figsize = (8,5), dpi=120)
mlp.rc('font',family='Times New Roman')
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
microdados_selecionados_semZero = microdados_selecionados.groupby('Ano de fabricação do dispositivo Wi-Fi').mean()
width_bar=0.30
ym= microdados_selecionados_semZero['Valor médio para 2,4 GHz CARREGADO']
yp= microdados_selecionados_semZero['Valor de pico para 2,4 GHz CARREGADO']
yd= microdados_selecionados_semZero['Valor médio para WI-FI DESLIGADO']
x = ym.index
barra_before=ax.bar(x-(width_bar),ym,width_bar,color ='grey',align='edge',label='Valor médio para 2,4 GHz' )
barra_medium=ax.bar(x,yp,width_bar,color ='red',align='edge',label='Valor de pico para 2,4 GHz' )
barra_aftter=ax.bar(x+(width_bar),yd,width_bar, color ='black',align='edge',label='Equipamento desligado' )
#eixox=x
#plt.xticks(x,eixox)
#plt.title("Intensidade de campo elétrico ")
plt.xlabel('Ano de Fabricação do Ponto de Acesso')
plt.ylabel('Intensidade de Campo elétrico (V/m)')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74e02ecf67c6> in <cell line: 5>()
#       3 import plotly.express as px
#       4 fig,ax = plt.subplots(figsize = (8,5), dpi=120)
# ----> 5 mlp.rc('font',family='Times New Roman')
#       6 plt.rcParams['font.family'] = 'serif'
#       7 plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
#
# NameError: name 'mlp' is not defined

# %%
# diferença por ponto de acesso
fig,ax = plt.subplots(figsize = (15,8), dpi=120)

# retirar valores zero
indexSemZero = ~( microdados_selecionados['Valor médio para 5 GHz CARREGADO'] == 0)
microdados_selecionados_semZero = microdados_selecionados[indexSemZero]

#d = microdados_selecionados_per_year.groupby('Ano de fabricação do dispositivo Wi-Fi').mean()
width_bar=0.30
x=np.array(range(1,microdados_selecionados_per_year.shape[0]+1))
y4= microdados_selecionados_semZero['Valor médio para 2,4 GHz CARREGADO']
y5= microdados_selecionados_semZero['Valor médio para 5 GHz CARREGADO']
yd= microdados_selecionados_semZero['Valor médio para WI-FI DESLIGADO']
yj= microdados_selecionados_semZero['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)']
d1=y4-yd
d2=y5-yd
d3=yj-yd
barra_before=ax.bar(x-(width_bar),d1,width_bar,color ='grey',align='edge',label='2,4 GHz' )
barra_medium=ax.bar(x,d2,width_bar,color ='red',align='edge',label='5 GHz')
barra_aftter=ax.bar(x+(width_bar),d3,width_bar,color ='black',align='edge',label='2,4 e 5 GHz')
plt.xlabel('Ponto de Acesso')
plt.ylabel('Intensidade a mais que a referência (V/m)')
plt.legend()
#comando para ocultar a informação do eixo x
#plt.gca().axes.get_xaxis().set_visible(False)

print('Maior diferença de 2.4 = {}'.format(d1.max()))
print('Maior diferença de 5 GHz = {}'.format(d2.max()))
print('Maior diferença 2.4 e 5 GHz = {}'.format(d3.max()))
# Out:
# Maior diferença de 2.4 = 4.640000000000001
# Maior diferença de 5 GHz = 4.32
# Maior diferença 2.4 e 5 GHz = 3.9699999999999998

# %%
# diferença por ano de fabricação
fig,ax = plt.subplots(figsize = (8,5), dpi=120)

# retirar valores zero
indexSemZero = ~( microdados_selecionados['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)'] == 0)
microdados_selecionados_per_year = microdados_selecionados[indexSemZero]

#d = microdados_selecionados_per_year.groupby('Ano de fabricação do dispositivo Wi-Fi').mean()
width_bar=0.30
x=microdados_selecionados_per_year['Ano de fabricação do dispositivo Wi-Fi']
y4= microdados_selecionados_per_year['Valor médio para 2,4 GHz CARREGADO']
y5= microdados_selecionados_per_year['Valor médio para 5 GHz CARREGADO']
yd= microdados_selecionados_per_year['Valor médio para WI-FI DESLIGADO']
yj= microdados_selecionados_per_year['Valor médio para 2,4 GHz  + 5 GHz (CARREGADO)']
d1=y4-yd
d2=y5-yd
d3=yj-yd
barra_before=ax.bar(x-(width_bar),d1,width_bar,color ='grey',align='edge',label='2,4 GHz' )
barra_medium=ax.bar(x,d2,width_bar,color ='red',align='edge',label='5 GHz')
barra_aftter=ax.bar(x+(width_bar),d3,width_bar,color ='black',align='edge',label='2,4 e 5 GHz')
plt.xlabel('Ponto de Acesso')
plt.ylabel('Intensidade a mais que a referência (V/m)')
plt.legend()
#comando para ocultar a informação do eixo x
#plt.gca().axes.get_xaxis().set_visible(False)
